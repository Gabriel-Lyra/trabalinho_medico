# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
dataset1 = pd.DataFrame(pd.read_csv('cor.csv', index_col=0))

# %%
dataset2 = pd.DataFrame(pd.read_csv('sexo.csv', index_col=0))

# %%
dataset3 = pd.DataFrame(pd.read_csv('idade.csv', index_col=0))

# %% [markdown]
# Dados obtidos no dataSUS

# %%
dataset1['Ano/mes processamento'] = dataset1.index
dataset1
# Out:
#                        Branca  Preta  ...  Total  Ano/mes processamento
# Ano/mes processamento                 ...
# 2017                      249     67  ...   1138                   2017
# Janeiro/2017                9      4  ...     54           Janeiro/2017
# Fevereiro/2017             13      0  ...     55         Fevereiro/2017
# Marco/2017                 24      8  ...     95             Marco/2017
# Abril/2017                 38      6  ...    114             Abril/2017
# ...                       ...    ...  ...    ...                    ...
# Setembro/2021              24     11  ...    189          Setembro/2021
# Outubro/2021               26      8  ...    232           Outubro/2021
# Novembro/2021              37     10  ...    217          Novembro/2021
# Dezembro/2021              17     10  ...    130          Dezembro/2021
# Total                    1265    558  ...   6703                  Total
#
# [66 rows x 7 columns]

# %%
dataset2['Ano/mes processamento'] = dataset2.index
dataset2
# Out:
#                        Masc   Fem  Total Ano/mes processamento
# Ano/mes processamento
# 2017                    622   516   1138                  2017
# Janeiro/2017             36    18     54          Janeiro/2017
# Fevereiro/2017           26    29     55        Fevereiro/2017
# Marco/2017               53    42     95            Marco/2017
# Abril/2017               61    53    114            Abril/2017
# ...                     ...   ...    ...                   ...
# Setembro/2021            87   102    189         Setembro/2021
# Outubro/2021            120   112    232          Outubro/2021
# Novembro/2021           118    99    217         Novembro/2021
# Dezembro/2021            73    57    130         Dezembro/2021
# Total                  3712  2991   6703                 Total
#
# [66 rows x 4 columns]

# %%
dataset3['Ano/mes processamento'] = dataset3.index
dataset3
# Out:
#                        1 a 4 anos  5 a 9 anos  ...  Total  Ano/mes processamento
# Ano/mes processamento                          ...
# 2017                          645         328  ...   1138                   2017
# Janeiro/2017                   32          19  ...     54           Janeiro/2017
# Fevereiro/2017                 36          13  ...     55         Fevereiro/2017
# Marco/2017                     57          26  ...     95             Marco/2017
# Abril/2017                     64          32  ...    114             Abril/2017
# ...                           ...         ...  ...    ...                    ...
# Setembro/2021                 110          59  ...    189          Setembro/2021
# Outubro/2021                  126          85  ...    232           Outubro/2021
# Novembro/2021                 115          75  ...    217          Novembro/2021
# Dezembro/2021                  65          49  ...    130          Dezembro/2021
# ...

# %%
plotting = dataset1.drop((['2017','2018','2019','2020','2021','Total']))

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(plotting['Ano/mes processamento'], plotting['Branca'], color='g', label='Branca', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['Preta'], color='r', label='Preta', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['Parda'], color='b', label='Parda', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['Amarela'], color='black', label='Amarela', linewidth=3)
plt.xticks(np.arange(0, len(plotting['Ano/mes processamento'])+1, 6))
plt.show()

# %%
plotting = dataset2.drop((['2017','2018','2019','2020','2021','Total']))

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(plotting['Ano/mes processamento'], plotting['Masc'], color='g', label='Masc', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['Fem'], color='b', label='Fem', linewidth=3)
plt.xticks(np.arange(0, len(plotting['Ano/mes processamento'])+1, 6))
plt.show()

# %%
plotting = dataset3.drop((['2017','2018','2019','2020','2021','Total']))

plt.rcParams["figure.figsize"] = (20,10)
plt.plot(plotting['Ano/mes processamento'], plotting['1 a 4 anos'], color='g', label='1 a 4 anos', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['5 a 9 anos'], color='r', label='5 a 9 anos', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['10 a 14 anos'], color='b', label='10 a 14 anos', linewidth=3)
plt.plot(plotting['Ano/mes processamento'], plotting['15 a 19 anos'], color='black', label='15 a 19 anos', linewidth=3)
plt.xticks(np.arange(0, len(plotting['Ano/mes processamento'])+1, 6))
plt.show()

# %%
população_total_1_4_anos = 987615
população_total_5_9_anos = 1092991
população_total_10_14_anos = 1305033
população_total_15_19_anos = 1270276

# %% [markdown]
# Números populacionais coletados na fonte: https://censo2010.ibge.gov.br/sinopse/webservice/frm_piramide.php?codigo=33

# %%
total_casos_2017 = 1138
total_casos_2018 = 1214
total_casos_2019 = 1307
total_casos_2020 = 962
total_casos_2021 = 2082

# %%
constante = 100000

coeficiente_incidencia_asma_1_4_anos_2017 = total_casos_2017/população_total_1_4_anos * constante
coeficiente_incidencia_asma_5_9_anos_2017 = total_casos_2017/população_total_5_9_anos * constante
coeficiente_incidencia_asma_10_14_anos_2017 = total_casos_2017/população_total_10_14_anos * constante
coeficiente_incidencia_asma_15_19_anos_2017 = total_casos_2017/população_total_15_19_anos * constante

coeficiente_incidencia_asma_1_4_anos_2018 = total_casos_2018/população_total_1_4_anos * constante
coeficiente_incidencia_asma_5_9_anos_2018 = total_casos_2018/população_total_5_9_anos * constante
coeficiente_incidencia_asma_10_14_anos_2018 = total_casos_2018/população_total_10_14_anos * constante
coeficiente_incidencia_asma_15_19_anos_2018 = total_casos_2018/população_total_15_19_anos * constante

coeficiente_incidencia_asma_1_4_anos_2019 = total_casos_2019/população_total_1_4_anos * constante
coeficiente_incidencia_asma_5_9_anos_2019 = total_casos_2019/população_total_5_9_anos * constante
coeficiente_incidencia_asma_10_14_anos_2019 = total_casos_2019/população_total_10_14_anos * constante
coeficiente_incidencia_asma_15_19_anos_2019 = total_casos_2019/população_total_15_19_anos * constante

coeficiente_incidencia_asma_1_4_anos_2020 = total_casos_2020/população_total_1_4_anos * constante
coeficiente_incidencia_asma_5_9_anos_2020 = total_casos_2020/população_total_5_9_anos * constante
coeficiente_incidencia_asma_10_14_anos_2020 = total_casos_2020/população_total_10_14_anos * constante
coeficiente_incidencia_asma_15_19_anos_2020 = total_casos_2020/população_total_15_19_anos * constante

coeficiente_incidencia_asma_1_4_anos_2021 = total_casos_2021/população_total_1_4_anos * constante
coeficiente_incidencia_asma_5_9_anos_2021 = total_casos_2021/população_total_5_9_anos * constante
coeficiente_incidencia_asma_10_14_anos_2021 = total_casos_2021/população_total_10_14_anos * constante
coeficiente_incidencia_asma_15_19_anos_2021 = total_casos_2021/população_total_15_19_anos * constante

# %%
data = {'Ano': ['2017', '2017', '2017', '2017',
                '2018', '2018', '2018', '2018',
                '2019', '2019', '2019', '2019',
                '2020', '2020', '2020', '2020',
                '2021', '2021', '2021', '2021'],
        'Coeficiente': [coeficiente_incidencia_asma_1_4_anos_2017, coeficiente_incidencia_asma_5_9_anos_2017, coeficiente_incidencia_asma_10_14_anos_2017, coeficiente_incidencia_asma_15_19_anos_2017,
                        coeficiente_incidencia_asma_1_4_anos_2018, coeficiente_incidencia_asma_5_9_anos_2018, coeficiente_incidencia_asma_10_14_anos_2018, coeficiente_incidencia_asma_15_19_anos_2018,
                        coeficiente_incidencia_asma_1_4_anos_2019, coeficiente_incidencia_asma_5_9_anos_2019, coeficiente_incidencia_asma_10_14_anos_2019, coeficiente_incidencia_asma_15_19_anos_2019,
                        coeficiente_incidencia_asma_1_4_anos_2020, coeficiente_incidencia_asma_5_9_anos_2020, coeficiente_incidencia_asma_10_14_anos_2020, coeficiente_incidencia_asma_15_19_anos_2020,
                        coeficiente_incidencia_asma_1_4_anos_2021, coeficiente_incidencia_asma_5_9_anos_2021, coeficiente_incidencia_asma_10_14_anos_2021, coeficiente_incidencia_asma_15_19_anos_2021]}

# %%
df = pd.DataFrame(data, index =['1 a 4 anos', '5 a 9 anos', '10 a 14 anos', '15 a 19 anos',
                  '1 a 4 anos', '5 a 9 anos', '10 a 14 anos', '15 a 19 anos',
                  '1 a 4 anos', '5 a 9 anos', '10 a 14 anos', '15 a 19 anos',
                  '1 a 4 anos', '5 a 9 anos', '10 a 14 anos', '15 a 19 anos',
                  '1 a 4 anos', '5 a 9 anos', '10 a 14 anos', '15 a 19 anos'])

# %%
df
# Out:
#                Ano  Coeficiente
# 1 a 4 anos    2017   115.227087
# 5 a 9 anos    2017   104.117966
# 10 a 14 anos  2017    87.200860
# 15 a 19 anos  2017    89.586830
# 1 a 4 anos    2018   122.922394
# 5 a 9 anos    2018   111.071363
# 10 a 14 anos  2018    93.024468
# 15 a 19 anos  2018    95.569782
# 1 a 4 anos    2019   132.339019
# 5 a 9 anos    2019   119.580125
# 10 a 14 anos  2019   100.150724
# 15 a 19 anos  2019   102.891025
# 1 a 4 anos    2020    97.406378
# 5 a 9 anos    2020    88.015363
# 10 a 14 anos  2020    73.714611
# 15 a 19 anos  2020    75.731573
# 1 a 4 anos    2021   210.810893
# 5 a 9 anos    2021   190.486472
# 10 a 14 anos  2021   159.536196
# 15 a 19 anos  2021   163.901388
